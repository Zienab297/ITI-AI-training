# %% [markdown]
# **This notebook is an exercise in the [Computer Vision](https://www.kaggle.com/learn/computer-vision) course.  You can reference the tutorial at [this link](https://www.kaggle.com/ryanholbrook/custom-convnets).**
#
# ---

# %% [markdown]
# # Introduction #
#
# In these exercises, you'll build a custom convnet with performance competitive to the VGG16 model from Lesson 1.
#
# Get started by running the code cell below.

# %%
# Setup feedback system
from learntools.core import binder
binder.bind(globals())
from learntools.computer_vision.ex5 import *

# Imports
import os, warnings
import matplotlib.pyplot as plt
from matplotlib import gridspec

import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing import image_dataset_from_directory

# Reproducability
def set_seed(seed=31415):
    np.random.seed(seed)
    tf.random.set_seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    os.environ['TF_DETERMINISTIC_OPS'] = '1'
set_seed()

# Set Matplotlib defaults
plt.rc('figure', autolayout=True)
plt.rc('axes', labelweight='bold', labelsize='large',
       titleweight='bold', titlesize=18, titlepad=10)
plt.rc('image', cmap='magma')
warnings.filterwarnings("ignore") # to clean up output cells


# Load training and validation sets
ds_train_ = image_dataset_from_directory(
    '../input/car-or-truck/train',
    labels='inferred',
    label_mode='binary',
    image_size=[128, 128],
    interpolation='nearest',
    batch_size=64,
    shuffle=True,
)
ds_valid_ = image_dataset_from_directory(
    '../input/car-or-truck/valid',
    labels='inferred',
    label_mode='binary',
    image_size=[128, 128],
    interpolation='nearest',
    batch_size=64,
    shuffle=False,
)

# Data Pipeline
def convert_to_float(image, label):
    image = tf.image.convert_image_dtype(image, dtype=tf.float32)
    return image, label

AUTOTUNE = tf.data.experimental.AUTOTUNE
ds_train = (
    ds_train_
    .map(convert_to_float)
    .cache()
    .prefetch(buffer_size=AUTOTUNE)
)
ds_valid = (
    ds_valid_
    .map(convert_to_float)
    .cache()
    .prefetch(buffer_size=AUTOTUNE)
)
# Out:
# 2024-09-04 12:44:51.597806: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-09-04 12:44:51.597945: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-09-04 12:44:51.719289: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Found 5117 files belonging to 2 classes.
# Found 5051 files belonging to 2 classes.

# %% [markdown]
# # Design a Convnet #
#
# Let's design a convolutional network with a block architecture like we saw in the tutorial. The model from the example had three blocks, each with a single convolutional layer. Its performance on the "Car or Truck" problem was okay, but far from what the pretrained VGG16 could achieve. It might be that our simple network lacks the ability to extract sufficiently complex features. We could try improving the model either by adding more blocks or by adding convolutions to the blocks we have.
#
# Let's go with the second approach. We'll keep the three block structure, but increase the number of `Conv2D` layer in the second block to two, and in the third block to three.
#
# <figure>
# <!-- <img src="./images/2-convmodel-2.png" width="250" alt="Diagram of a convolutional model."> -->
# <img src="https://storage.googleapis.com/kaggle-media/learn/images/Vko6nCK.png" width="250" alt="Diagram of a convolutional model.">
# </figure>
#
# # 1) Define Model #
#
# Given the diagram above, complete the model by defining the layers of the third block.

# %%
from tensorflow import keras
from tensorflow.keras import layers

model = keras.Sequential([
    # Block One
    layers.Conv2D(filters=32, kernel_size=3, activation='relu', padding='same',
                  input_shape=[128, 128, 3]),
    layers.MaxPool2D(),

    # Block Two
    layers.Conv2D(filters=64, kernel_size=3, activation='relu', padding='same'),
    layers.MaxPool2D(),

    # Block Three
    # YOUR CODE HERE
    layers.Conv2D(filters=128, kernel_size=3, activation='relu', padding='same'),
    layers.Conv2D(filters=128, kernel_size=3, activation='relu', padding='same'),
    layers.MaxPool2D(),

    # Head
    layers.Flatten(),
    layers.Dense(6, activation='relu'),
    layers.Dropout(0.2),
    layers.Dense(1, activation='sigmoid'),
])

# Check your answer
q_1.check()
# Out:
# Correct

# %%
# Lines below will give you a hint or solution code
#q_1.hint()
#q_1.solution()

# %% [markdown]
# # 2) Compile #
#
# To prepare for training, compile the model with an appropriate loss and accuracy metric for the "Car or Truck" dataset.

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(epsilon=0.01),
    loss='binary_crossentropy',
    metrics=['binary_accuracy']
    # YOUR CODE HERE: Add loss and metric
)

# Check your answer
q_2.check()
# Out:
# Correct

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(epsilon=0.01),
    loss='binary_crossentropy',
    metrics=['binary_accuracy'],
)
q_2.assert_check_passed()
# Out:
# Correct

# %%
# Lines below will give you a hint or solution code
#q_2.hint()
#q_2.solution()

# %% [markdown]
# Finally, let's test the performance of this new model. First run this cell to fit the model to the training set.

# %%
history = model.fit(
    ds_train,
    validation_data=ds_valid,
    epochs=50,
)
# Out:
# Epoch 1/50
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1725454136.847748     103 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 80/80 [==============================] - 21s 193ms/step - loss: 0.6752 - binary_accuracy: 0.5861 - val_loss: 0.6594 - val_binary_accuracy: 0.6036
# Epoch 2/50
# 80/80 [==============================] - 3s 42ms/step - loss: 0.6609 - binary_accuracy: 0.5988 - val_loss: 0.6505 - val_binary_accuracy: 0.6141
# Epoch 3/50
# 80/80 [==============================] - 3s 41ms/step - loss: 0.6501 - binary_accuracy: 0.6140 - val_loss: 0.6447 - val_binary_accuracy: 0.6098
# Epoch 4/50
# 80/80 [==============================] - 3s 41ms/step - loss: 0.6408 - binary_accuracy: 0.6244 - val_loss: 0.6291 - val_binary_accuracy: 0.6369
# Epoch 5/50
# 80/80 [==============================] - 3s 41ms/step - loss: 0.6276 - binary_accuracy: 0.6435 - val_loss: 0.6250 - val_binary_accuracy: 0.6385
# Epoch 6/50
# 80/80 [==============================] - 3s 41ms/step - loss: 0.6133 - binary_accuracy: 0.6541 - val_loss: 0.6021 - val_binary_accuracy: 0.6678
# Epoch 7/50
# 80/80 [==============================] - 3s 42ms/step - loss: 0.6050 - binary_accuracy: 0.6660 - val_loss: 0.5972 - val_binary_accuracy: 0.6717
# Epoch 8/50
# 80/80 [==============================] - 3s 41ms/step - loss: 0.5937 - binary_accuracy: 0.6840 - val_loss: 0.5948 - val_binary_accuracy: 0.6753
# Epoch 9/50
# 80/80 [==============================] - 3s 40ms/step - loss: 0.5854 - binary_accuracy: 0.6945 - val_loss: 0.5813 - val_binary_accuracy: 0.6844
# Epoch 10/50
# 80/80 [==============================] - 3s 41ms/step - loss: 0.5612 - binary_accuracy: 0.7174 - val_loss: 0.5584 - val_binary_accuracy: 0.7139
# Epoch 11/50
# 80/80 [==============================] - 3s 41ms/step - loss: 0.5404 - binary_accuracy: 0.7350 - val_loss: 0.5360 - val_binary_accuracy: 0.7309
# Epoch 12/50
# 80/80 [==============================] - 3s 40ms/step - loss: 0.5146 - binary_accuracy: 0.7518 - val_loss: 0.5377 - val_binary_accuracy: 0.7367
# Epoch 13/50
# 80/80 [==============================] - 3s 42ms/step - loss: 0.4802 - binary_accuracy: 0.7696 - val_loss: 0.4963 - val_binary_accuracy: 0.7614
# Epoch 14/50
# 80/80 [==============================] - 3s 41ms/step - loss: 0.4558 - binary_accuracy: 0.7905 - val_loss: 0.5255 - val_binary_accuracy: 0.7488
# Epoch 15/50
# 80/80 [==============================] - 3s 41ms/step - loss: 0.4226 - binary_accuracy: 0.8110 - val_loss: 0.4734 - val_binary_accuracy: 0.7785
# Epoch 16/50
# 80/80 [==============================] - 4s 47ms/step - loss: 0.4049 - binary_accuracy: 0.8204 - val_loss: 0.4519 - val_binary_accuracy: 0.7925
# Epoch 17/50
# 80/80 [==============================] - 3s 41ms/step - loss: 0.3565 - binary_accuracy: 0.8450 - val_loss: 0.4717 - val_binary_accuracy: 0.7945
# Epoch 18/50
# 80/80 [==============================] - 3s 41ms/step - loss: 0.3328 - binary_accuracy: 0.8560 - val_loss: 0.4596 - val_binary_accuracy: 0.7994
# Epoch 19/50
# 80/80 [==============================] - 3s 41ms/step - loss: 0.3164 - binary_accuracy: 0.8663 - val_loss: 0.4856 - val_binary_accuracy: 0.7727
# Epoch 20/50
# 80/80 [==============================] - 3s 41ms/step - loss: 0.2894 - binary_accuracy: 0.8853 - val_loss: 0.4890 - val_binary_accuracy: 0.7666
# Epoch 21/50
# 80/80 [==============================] - 3s 41ms/step - loss: 0.2547 - binary_accuracy: 0.8921 - val_loss: 0.5092 - val_binary_accuracy: 0.7929
# Epoch 22/50
# 80/80 [==============================] - 3s 42ms/step - loss: 0.2298 - binary_accuracy: 0.9058 - val_loss: 0.4510 - val_binary_accuracy: 0.8008
# Epoch 23/50
# 80/80 [==============================] - 3s 41ms/step - loss: 0.2185 - binary_accuracy: 0.9080 - val_loss: 0.4676 - val_binary_accuracy: 0.8097
# Epoch 24/50
# 80/80 [==============================] - 3s 41ms/step - loss: 0.2121 - binary_accuracy: 0.9074 - val_loss: 0.4921 - val_binary_accuracy: 0.8113
# Epoch 25/50
# 80/80 [==============================] - 3s 41ms/step - loss: 0.2171 - binary_accuracy: 0.9019 - val_loss: 0.4578 - val_binary_accuracy: 0.8297
# Epoch 26/50
# 80/80 [==============================] - 3s 41ms/step - loss: 0.2116 - binary_accuracy: 0.9078 - val_loss: 0.4493 - val_binary_accuracy: 0.8307
# Epoch 27/50
# 80/80 [==============================] - 3s 41ms/step - loss: 0.1722 - binary_accuracy: 0.9267 - val_loss: 0.4967 - val_binary_accuracy: 0.8212
# Epoch 28/50
# 80/80 [==============================] - 3s 41ms/step - loss: 0.1534 - binary_accuracy: 0.9347 - val_loss: 0.5048 - val_binary_accuracy: 0.8167
# Epoch 29/50
# 80/80 [==============================] - 3s 41ms/step - loss: 0.1255 - binary_accuracy: 0.9470 - val_loss: 0.5298 - val_binary_accuracy: 0.8345
# Epoch 30/50
# 80/80 [==============================] - 3s 41ms/step - loss: 0.1359 - binary_accuracy: 0.9425 - val_loss: 0.7344 - val_binary_accuracy: 0.8042
# Epoch 31/50
# 80/80 [==============================] - 3s 41ms/step - loss: 0.1185 - binary_accuracy: 0.9513 - val_loss: 0.5830 - val_binary_accuracy: 0.8285
# Epoch 32/50
# 80/80 [==============================] - 3s 41ms/step - loss: 0.1022 - binary_accuracy: 0.9584 - val_loss: 0.8231 - val_binary_accuracy: 0.8084
# Epoch 33/50
# 80/80 [==============================] - 3s 41ms/step - loss: 0.1027 - binary_accuracy: 0.9603 - val_loss: 0.5917 - val_binary_accuracy: 0.8274
# Epoch 34/50
# 80/80 [==============================] - 3s 41ms/step - loss: 0.0890 - binary_accuracy: 0.9679 - val_loss: 0.6608 - val_binary_accuracy: 0.8177
# Epoch 35/50
# 80/80 [==============================] - 3s 41ms/step - loss: 0.0886 - binary_accuracy: 0.9674 - val_loss: 0.6958 - val_binary_accuracy: 0.8145
# Epoch 36/50
# 80/80 [==============================] - 3s 41ms/step - loss: 0.0774 - binary_accuracy: 0.9717 - val_loss: 0.7498 - val_binary_accuracy: 0.8048
# Epoch 37/50
# 80/80 [==============================] - 3s 41ms/step - loss: 0.0909 - binary_accuracy: 0.9658 - val_loss: 0.5801 - val_binary_accuracy: 0.8373
# Epoch 38/50
# 80/80 [==============================] - 3s 41ms/step - loss: 0.1003 - binary_accuracy: 0.9627 - val_loss: 0.5530 - val_binary_accuracy: 0.8394
# Epoch 39/50
# 80/80 [==============================] - 3s 41ms/step - loss: 0.0786 - binary_accuracy: 0.9689 - val_loss: 0.5671 - val_binary_accuracy: 0.8341
# Epoch 40/50
# 80/80 [==============================] - 3s 41ms/step - loss: 0.0818 - binary_accuracy: 0.9732 - val_loss: 0.5467 - val_binary_accuracy: 0.8410
# Epoch 41/50
# 80/80 [==============================] - 3s 41ms/step - loss: 0.0638 - binary_accuracy: 0.9789 - val_loss: 0.6236 - val_binary_accuracy: 0.8396
# Epoch 42/50
# 80/80 [==============================] - 3s 42ms/step - loss: 0.0406 - binary_accuracy: 0.9867 - val_loss: 0.6574 - val_binary_accuracy: 0.8460
# Epoch 43/50
# 80/80 [==============================] - 3s 41ms/step - loss: 0.0393 - binary_accuracy: 0.9881 - val_loss: 0.7919 - val_binary_accuracy: 0.8468
# Epoch 44/50
# 80/80 [==============================] - 3s 41ms/step - loss: 0.0299 - binary_accuracy: 0.9910 - val_loss: 0.8059 - val_binary_accuracy: 0.8458
# Epoch 45/50
# 80/80 [==============================] - 3s 41ms/step - loss: 0.0298 - binary_accuracy: 0.9894 - val_loss: 0.7051 - val_binary_accuracy: 0.8485
# Epoch 46/50
# 80/80 [==============================] - 3s 41ms/step - loss: 0.0279 - binary_accuracy: 0.9924 - val_loss: 0.7937 - val_binary_accuracy: 0.8527
# Epoch 47/50
# 80/80 [==============================] - 3s 41ms/step - loss: 0.0269 - binary_accuracy: 0.9920 - val_loss: 0.8422 - val_binary_accuracy: 0.8472
# Epoch 48/50
# 80/80 [==============================] - 3s 41ms/step - loss: 0.0278 - binary_accuracy: 0.9943 - val_loss: 0.9691 - val_binary_accuracy: 0.8462
# Epoch 49/50
# 80/80 [==============================] - 3s 42ms/step - loss: 0.0301 - binary_accuracy: 0.9920 - val_loss: 0.9631 - val_binary_accuracy: 0.8493
# Epoch 50/50
# 80/80 [==============================] - 3s 41ms/step - loss: 0.0235 - binary_accuracy: 0.9926 - val_loss: 0.9415 - val_binary_accuracy: 0.8523

# %% [markdown]
# And now run the cell below to plot the loss and metric curves for this training run.

# %%
import pandas as pd
history_frame = pd.DataFrame(history.history)
history_frame.loc[:, ['loss', 'val_loss']].plot()
history_frame.loc[:, ['binary_accuracy', 'val_binary_accuracy']].plot();

# %% [markdown]
# # 3) Train the Model #
#
# How would you interpret these training curves? Did this model improve upon the model from the tutorial?

# %%
# View the solution (Run this code cell to receive credit!)
q_3.check()
# Out:
# Correct:
#
#
# The learning curves for the model from the tutorial diverged fairly rapidly. This would indicate that it was prone to overfitting and in need of some regularization. The additional layer in our new model would make it even more prone to overfitting. However, adding some regularization with the `Dropout` layer helped prevent this. These changes improved the validation accuracy of the model by several points.

# %% [markdown]
# # Conclusion #
#
# These exercises showed you how to design a custom convolutional network to solve a specific classification problem. Though most models these days will be built on top of a pretrained base, it certain circumstances a smaller custom convnet might still be preferable -- such as with a smaller or unusual dataset or when computing resources are very limited. As you saw here, for certain problems they can perform just as well as a pretrained model.
#
# # Keep Going #
#
# Continue on to [**Lesson 6**](https://www.kaggle.com/ryanholbrook/data-augmentation), where you'll learn a widely-used technique that can give a boost to your training data: **data augmentation**.

# %% [markdown]
# ---
#
#
#
#
# *Have questions or comments? Visit the [course discussion forum](https://www.kaggle.com/learn/computer-vision/discussion) to chat with other learners.*
